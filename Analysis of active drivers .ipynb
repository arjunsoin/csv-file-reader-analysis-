# %%
import numpy as np 
import pandas as pd

# %%
data_file = pd.read_csv('output.csv')

# %%
print(data_file)
# Out:
#     Collector  Behind
# 0    Chandini  -21600
# 1    Chandini  -16700
# 2    Chandini  -23760
# 3    Chandini   -7200
# 4    Chandini   -6400
# 5    Chandini   -5800
# 6    Chandini   -1320
# 7    Chandini   -3000
# 8    Chandini   -5580
# 9    Chandini   -4225
# 10   Chandini   -3400
# 11   Chandini   -4500
# 12   Chandini    3025
# 13   Chandini    1275
# 14   Chandini    4400
# 15   Chandini    -500
# 16   Chandini   -1950
# 17   Chandini    4865
# 18   Chandini    1175
# 19   Chandini   -1980
# 20   Chandini   -1670
# 21   Chandini    8700
# 22   Chandini   15550
# 23   Chandini   12450
# 24   Chandini    5110
# 25   Chandini    6450
# 26   Chandini   13800
# 27   Chandini   14170
# 28   Chandini   16100
# 29   Chandini   21450
# ..        ...     ...
# 140     Sadiq   34375
# 141     Sadiq   30470
# 142     Sadiq   34420
# 143     Sadiq   43100
# 144     Sadiq   39550
# 145     Sadiq   47900
# 146     Sadiq   45360
# 147     Sadiq   49349
# 148     Sadiq   57000
# ...

# %%
data_file.describe()
# Out:
#               Behind
# count     170.000000
# mean    21465.923529
# std     22985.384834
# min    -37600.000000
# 25%      7206.250000
# 50%     19050.000000
# 75%     32465.000000
# max    107700.000000

# %%
chandini = data_file.iloc[:61]

# %%
chandini.describe()
# Out:
#               Behind
# count      61.000000
# mean    23043.852459
# std     28396.587550
# min    -23760.000000
# 25%      -500.000000
# 50%     19200.000000
# 75%     40715.000000
# max    107700.000000

# %%
# %matplotlib inline
import matplotlib.pyplot as plt 
plt.style.use('ggplot')

# %%
chandini.plot()

# %%
plt.figure()
chandini.plot(kind = 'barh')
plt.axhline(0, color='k')

# %%
chandini.plot(kind = 'hist')

# %%
chandini.plot.box()

# %%
from pandas.plotting import bootstrap_plot

# %%
print ('check')
# Out:
# check

# %%
values = chandini.ix[:,'Behind']

# %%
values.plot()

# %%
bootstrap_plot(values)

# %%
nagaraj = data_file.iloc[62:100]
raghu = data_file.iloc[100:102]
sadiq = data_file .iloc[102:150]
savithri = data_file.iloc[150:170]

print (nagaraj.describe())
print(raghu.describe())
print(sadiq.describe())
print(savithri.describe())
# Out:
# 0    -21600
# 1    -16700
# 2    -23760
# 3     -7200
# 4     -6400
# 5     -5800
# 6     -1320
# 7     -3000
# 8     -5580
# 9     -4225
# 10    -3400
# 11    -4500
# 12     3025
# 13     1275
# 14     4400
# 15     -500
# 16    -1950
# 17     4865
# 18     1175
# 19    -1980
# 20    -1670
# 21     8700
# 22    15550
# 23    12450
# 24     5110
# 25     6450
# 26    13800
# 27    14170
# 28    16100
# 29    21450
# 30    18890
# 31    19200
# 32    19825
# 33    20825
# 34    21300
# 35    22250
# 36    24325
# 37    25900
# 38    30070
# 39    29500
# 40    29850
# 41    25600
# 42    36100
# 43    34700
# 44    39800
# 45    40715
# 46    41850
# 47    42800
# 48    49825
# 49    44375
# Name: Behind, dtype: int64
#              Behind
# count     38.000000
# mean   25818.868421
# std    21101.569482
# min   -12975.000000
# 25%     8368.750000
# 50%    27550.000000
# 75%    38781.250000
# max    82100.000000
#              Behind
# count      2.000000
# mean   28294.000000
# ...

# %%
data_file.boxplot(by = 'Collector')

# %%
data_file.plot(by = 'Collector')

# %%
data_file.plot.bar(by = 'Collector')

# %%
amount = data_file.ix[:,'Behind']
# Out:
# c:\users\t-arsoin\appdata\local\programs\python\python36-32\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix
#   """Entry point for launching an IPython kernel.

# %%
plt.figure()
plt.plot(amount.iloc[:61],'r-')
plt.plot(amount.iloc[62:100],'b-')
plt.plot(amount.iloc[100:102],'y-')
plt.plot(amount.iloc[102:150],'k-')
plt.plot(amount.iloc[150:170],'g-')

# %%
print (chandini)
# Out:
#    Collector  Behind
# 0   Chandini  -21600
# 1   Chandini  -16700
# 2   Chandini  -23760
# 3   Chandini   -7200
# 4   Chandini   -6400
# 5   Chandini   -5800
# 6   Chandini   -1320
# 7   Chandini   -3000
# 8   Chandini   -5580
# 9   Chandini   -4225
# 10  Chandini   -3400
# 11  Chandini   -4500
# 12  Chandini    3025
# 13  Chandini    1275
# 14  Chandini    4400
# 15  Chandini    -500
# 16  Chandini   -1950
# 17  Chandini    4865
# 18  Chandini    1175
# 19  Chandini   -1980
# 20  Chandini   -1670
# 21  Chandini    8700
# 22  Chandini   15550
# 23  Chandini   12450
# 24  Chandini    5110
# 25  Chandini    6450
# 26  Chandini   13800
# 27  Chandini   14170
# 28  Chandini   16100
# 29  Chandini   21450
# ..       ...     ...
# 31  Chandini   19200
# 32  Chandini   19825
# 33  Chandini   20825
# 34  Chandini   21300
# 35  Chandini   22250
# 36  Chandini   24325
# 37  Chandini   25900
# 38  Chandini   30070
# 39  Chandini   29500
# 40  Chandini   29850
# 41  Chandini   25600
# ...

# %%
paid = chandini.ix[(chandini['Behind'] < 0)]

# %%
print (paid)
# Out:
#    Collector  Behind
# 0   Chandini  -21600
# 1   Chandini  -16700
# 2   Chandini  -23760
# 3   Chandini   -7200
# 4   Chandini   -6400
# 5   Chandini   -5800
# 6   Chandini   -1320
# 7   Chandini   -3000
# 8   Chandini   -5580
# 9   Chandini   -4225
# 10  Chandini   -3400
# 11  Chandini   -4500
# 15  Chandini    -500
# 16  Chandini   -1950
# 19  Chandini   -1980
# 20  Chandini   -1670

# %%
paid = sadiq.ix[(sadiq['Behind'] < 0)]
# Out:
# c:\users\t-arsoin\appdata\local\programs\python\python36-32\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix
#   """Entry point for launching an IPython kernel.

# %%
print (paid)
# Out:
#     Collector  Behind
# 102     Sadiq  -12700
# 103     Sadiq  -15230
# 104     Sadiq   -8740
# 105     Sadiq   -8430
# 106     Sadiq   -3090
